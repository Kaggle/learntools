# %% [markdown]
# # Intro
#
# **This is Siraj Raval's lesson in Time Series Prediction**
#
# After the end of this lesson, you will understand time series predictions and be able to beat Warren Buffet at predicting bitcoin movements.
#
#
# # Lesson

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('d4Sn6ny_5LI', width=800, height=450)

# %% [markdown]
# # Your Turn
# **After watching the video, get some [hands-on practice](https://www.kaggle.com/kernels/fork/2096013) with the time series techniques Siraj showed you.**
#
#
# ---
# Have questions, comments or feedback?  Bring them to [the Learn forum](https://www.kaggle.com/learn-forum)
